# %%
import pandas as pd
import os

# %%
file = os.path.join("..","Resource","raw_data.csv")
df = pd.read_csv(file)
df.head()
# Out:
#         ID  MS       Mp  VFN       Mh          Man      MMS  \
# 0  3034815  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 1  3034852  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 2  3034859  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 3  3034866  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 4  3034873  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
#
#                    TAN  T    Va  ...  Mt Enedc (g/km) Ewltp (g/km)  W (mm)  \
# 0  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 1  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 2  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 3  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 4  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
#
#   At1 (mm)  At2 (mm)      Ft  Fm  ec (cm3)  ep (KW)
# 0   1531.0    1531.0  DIESEL   M    1461.0     66.0
# ...

# %%
df.dtypes
# Out:
# ID                int64
# MS               object
# Mp               object
# VFN             float64
# Mh               object
# Man              object
# MMS              object
# TAN              object
# T                object
# Va               object
# Ve               object
# Mk               object
# Cn               object
# Ct               object
# Cr               object
# m (kg)          float64
# Mt              float64
# Enedc (g/km)    float64
# Ewltp (g/km)    float64
# W (mm)          float64
# At1 (mm)        float64
# At2 (mm)        float64
# Ft               object
# Fm               object
# ec (cm3)        float64
# ep (KW)         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ID                  0
# MS                  0
# Mp               6838
# VFN             24962
# Mh                  0
# Man                 0
# MMS              2192
# TAN                78
# T                  48
# Va                 73
# Ve                101
# Mk                 88
# Cn                 37
# Ct                  0
# Cr               6511
# m (kg)              4
# Mt              24952
# Enedc (g/km)      155
# Ewltp (g/km)    24952
# W (mm)              1
# At1 (mm)          277
# At2 (mm)         1087
# Ft                  2
# Fm                  0
# ec (cm3)          173
# ep (KW)           685
# dtype: int64

# %%
df.drop(['VFN','Mt','Ewltp (g/km)'], axis=1, inplace=True)
df.isnull().sum()
# Out:
# ID                 0
# MS                 0
# Mp              6838
# Mh                 0
# Man                0
# MMS             2192
# TAN               78
# T                 48
# Va                73
# Ve               101
# Mk                88
# Cn                37
# Ct                 0
# Cr              6511
# m (kg)             4
# Enedc (g/km)     155
# W (mm)             1
# At1 (mm)         277
# At2 (mm)        1087
# Ft                 2
# Fm                 0
# ec (cm3)         173
# ep (KW)          685
# dtype: int64

# %%
df.shape
# Out:
# (24962, 23)

# %%
df.dropna(how = 'any', inplace=True )

# %%
df.isnull().sum()
# Out:
# ID              0
# MS              0
# Mp              0
# Mh              0
# Man             0
# MMS             0
# TAN             0
# T               0
# Va              0
# Ve              0
# Mk              0
# Cn              0
# Ct              0
# Cr              0
# m (kg)          0
# Enedc (g/km)    0
# W (mm)          0
# At1 (mm)        0
# At2 (mm)        0
# Ft              0
# Fm              0
# ec (cm3)        0
# ep (KW)         0
# dtype: int64

# %%
df.shape
# Out:
# (12576, 23)

# %%
df.head(20)
# Out:
#          ID  MS       Mp       Mh          Man          MMS  \
# 0   3034815  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 1   3034852  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 2   3034859  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 3   3034866  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 4   3034873  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 5   3034951  FR  RENAULT  RENAULT  RENAULT SAS  RENAULT SAS
# 6   3034957  FR  RENAULT  RENAULT  RENAULT SAS  RENAULT SAS
# 7   3034963  FR  RENAULT  RENAULT  RENAULT SAS  RENAULT SAS
# 8   3044658  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 9   3044666  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 10  3044707  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 11  3044715  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 12  3044721  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 13  3035349  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# 14  3035357  FR  RENAULT  RENAULT  RENAULT SAS      RENAULT
# ...

# %%
df.dtypes
# Out:
# ID                int64
# MS               object
# Mp               object
# Mh               object
# Man              object
# MMS              object
# TAN              object
# T                object
# Va               object
# Ve               object
# Mk               object
# Cn               object
# Ct               object
# Cr               object
# m (kg)          float64
# Enedc (g/km)    float64
# W (mm)          float64
# At1 (mm)        float64
# At2 (mm)        float64
# Ft               object
# Fm               object
# ec (cm3)        float64
# ep (KW)         float64
# dtype: object

# %%
df.to_csv(os.path.join("..","Resource","clean_raw_data.csv"))
