# %%
import pandas as pd
import os

# %%
file = "Resources/mock_data.csv"
df = pd.read_csv(file)
df.head()
# Out:
#         ID  MS       Mp  VFN       Mh          Man      MMS  \
# 0  3034815  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 1  3034852  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 2  3034859  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 3  3034866  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
# 4  3034873  FR  RENAULT  NaN  RENAULT  RENAULT SAS  RENAULT
#
#                    TAN  T    Va  ...  Mt Enedc (g/km) Ewltp (g/km)  W (mm)  \
# 0  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 1  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 2  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 3  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
# 4  E2*2001/116*0327*80  R  2RAJ  ... NaN         95.0          NaN  2606.0
#
#   At1 (mm)  At2 (mm)      Ft  Fm  ec (cm3)  ep (KW)
# 0   1531.0    1531.0  DIESEL   M    1461.0     66.0
# ...

# %%
practice_df = df[['Mk', 'Ct','Cr', 'm (kg)','Enedc (g/km)','W (mm)','At1 (mm)','At2 (mm)','Ft','Fm','ec (cm3)','ep (KW)']]
practice_df.head()
# Out:
#         Mk  Ct  Cr  m (kg)  Enedc (g/km)  W (mm)  At1 (mm)  At2 (mm)      Ft  \
# 0  RENAULT  M1  M1    1253          95.0  2606.0    1531.0    1531.0  DIESEL
# 1  RENAULT  M1  M1    1253          95.0  2606.0    1531.0    1531.0  DIESEL
# 2  RENAULT  M1  M1    1253          95.0  2606.0    1531.0    1531.0  DIESEL
# 3  RENAULT  M1  M1    1253          95.0  2606.0    1531.0    1531.0  DIESEL
# 4  RENAULT  M1  M1    1253          95.0  2606.0    1531.0    1531.0  DIESEL
#
#   Fm  ec (cm3)  ep (KW)
# 0  M    1461.0     66.0
# 1  M    1461.0     66.0
# 2  M    1461.0     66.0
# 3  M    1461.0     66.0
# 4  M    1461.0     66.0

# %%
practice_df.dtypes
# Out:
# Mk               object
# Ct               object
# Cr               object
# m (kg)            int64
# Enedc (g/km)    float64
# W (mm)          float64
# At1 (mm)        float64
# At2 (mm)        float64
# Ft               object
# Fm               object
# ec (cm3)        float64
# ep (KW)         float64
# dtype: object

# %%
practice_df.rename({'Ct': 'Category Type Approved','Cr':'Category Registered', 'm(kg)':'Mass (kg)','Enedc (g/km)':'CO2 (g/km)','At1 (mm)':'Steering Axle (mm)','At2 (mm)':'Other Axle (mm)','ec (cm3)':'Engine Capacity (cm3)','ep (KW)':'Engine Power (KW)'}, axis=1, inplace=True)
practice_df.head(20)
# Out:
# /Users/abdulhakiim/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#          Mk Category Type Approved Category Registered  Mass (kg)  CO2 (g/km)  \
# 0   RENAULT                     M1                  M1       1253        95.0
# 1   RENAULT                     M1                  M1       1253        95.0
# 2   RENAULT                     M1                  M1       1253        95.0
# 3   RENAULT                     M1                  M1       1253        95.0
# 4   RENAULT                     M1                  M1       1253        95.0
# 5   RENAULT                     M1                  M1       1448       132.0
# ...

# %%
practice_df.isnull().sum()
# Out:
# Mk                          33
# Category Type Approved       0
# Category Registered       3066
# Mass (kg)                    0
# CO2 (g/km)                  45
# W (mm)                       1
# Steering Axle (mm)          70
# Other Axle (mm)            412
# Ft                           0
# Fm                           0
# Engine Capacity (cm3)       35
# Engine Power (KW)          429
# dtype: int64

# %%
practice_df.shape
# Out:
# (9999, 12)

# %%
practice_df.dropna(how = 'any', inplace=True )
# Out:
# /Users/abdulhakiim/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
practice_df.shape
# Out:
# (6486, 12)

# %%
practice_df.head(20)
# Out:
#          Mk Category Type Approved Category Registered  Mass (kg)  CO2 (g/km)  \
# 0   RENAULT                     M1                  M1       1253        95.0
# 1   RENAULT                     M1                  M1       1253        95.0
# 2   RENAULT                     M1                  M1       1253        95.0
# 3   RENAULT                     M1                  M1       1253        95.0
# 4   RENAULT                     M1                  M1       1253        95.0
# 5   RENAULT                     M1                  M1       1448       132.0
# 6   RENAULT                     M1                  M1       1448       132.0
# 7   RENAULT                     M1                  M1       1395       130.0
# 8   RENAULT                     M1                  M1       1253        95.0
# 9   RENAULT                     M1                  M1       1253        95.0
# 10  RENAULT                     M1                  M1       1253        95.0
# ...

# %%
practice_df.to_csv("Resources/mock_data_for_practice.csv")
